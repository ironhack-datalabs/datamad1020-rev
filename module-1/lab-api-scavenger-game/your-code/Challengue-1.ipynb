# %%
import os
import json
from dotenv import load_dotenv
import requests
import re
load_dotenv()
import http.client

# %%
token = os.getenv('token')

# %%
headers = {'Authorization': f'token{token}'}

# %%
url_forks = "https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/forks"

# %%
res = requests.get(url_forks, headers=headers).json()
print(res)
# Out:
# [{'id': 309172162, 'node_id': 'MDEwOlJlcG9zaXRvcnkzMDkxNzIxNjI=', 'name': 'datamad1020-rev', 'full_name': 'agalvezcorell/datamad1020-rev', 'private': False, 'owner': {'login': 'agalvezcorell', 'id': 57899051, 'node_id': 'MDQ6VXNlcjU3ODk5MDUx', 'avatar_url': 'https://avatars0.githubusercontent.com/u/57899051?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/agalvezcorell', 'html_url': 'https://github.com/agalvezcorell', 'followers_url': 'https://api.github.com/users/agalvezcorell/followers', 'following_url': 'https://api.github.com/users/agalvezcorell/following{/other_user}', 'gists_url': 'https://api.github.com/users/agalvezcorell/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/agalvezcorell/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/agalvezcorell/subscriptions', 'organizations_url': 'https://api.github.com/users/agalvezcorell/orgs', 'repos_url': 'https://api.github.com/users/agalvezcorell/repos', 'events_url': 'https://api.
# ...

# %%
list_language = []
for i in res:
    list_language.append(i['language'])

# %%
set(list_language)
# Out:
# {'Jupyter Notebook'}

# %%
url_commits = "https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/commits"
parameters = {"since": "2020-10-26T00:00:00Z", "until": "2020-11-01T00:00:00Z"}
response_commits = requests.get(url_commits, params=parameters, headers=headers)

# %%
response_commits.status_code
# Out:
# 200

# %%
data_commits = response_commits.json()

# %%
data_commits
# Out:
# [{'sha': '56c1aa10c26d062c4b19848da442f9d5cc0e9f30',
#   'node_id': 'MDY6Q29tbWl0MzA0MjQ4NTM5OjU2YzFhYTEwYzI2ZDA2MmM0YjE5ODQ4ZGE0NDJmOWQ1Y2MwZTlmMzA=',
#   'commit': {'author': {'name': 'ironhack-datalabs',
#     'email': 'agalvezcorell@gmail.com',
#     'date': '2020-10-30T09:29:13Z'},
#    'committer': {'name': 'ironhack-datalabs',
#     'email': 'agalvezcorell@gmail.com',
#     'date': '2020-10-30T09:29:13Z'},
#    'message': 'txt myproject',
#    'tree': {'sha': 'bdbe22c3904a29d980684618bcff2b910af816d5',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/trees/bdbe22c3904a29d980684618bcff2b910af816d5'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/commits/56c1aa10c26d062c4b19848da442f9d5cc0e9f30',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
len(data_commits)
# Out:
# 11
