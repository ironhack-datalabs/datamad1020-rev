# %% [markdown]
# # Challenge 1: Fork Languages

# %%
import os
from dotenv import load_dotenv
import json
import requests
import re
import base64
load_dotenv()
# Out:
# True

# %%
token = os.getenv("token")

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/forks'
response = requests.get(url, headers={"Authorization": token})
response.json()
# Out:
# [{'id': 309172162,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMDkxNzIxNjI=',
#   'name': 'datamad1020-rev',
#   'full_name': 'agalvezcorell/datamad1020-rev',
#   'private': False,
#   'owner': {'login': 'agalvezcorell',
#    'id': 57899051,
#    'node_id': 'MDQ6VXNlcjU3ODk5MDUx',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/57899051?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/agalvezcorell',
#    'html_url': 'https://github.com/agalvezcorell',
#    'followers_url': 'https://api.github.com/users/agalvezcorell/followers',
#    'following_url': 'https://api.github.com/users/agalvezcorell/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/agalvezcorell/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/agalvezcorell/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/agalvezcorell/subscriptions',
#    'organizations_url': 'https://api.github.com/users/agalvezcorell/orgs',
# ...

# %%
arr=[]
for i in response.json():
    arr.append(i['language']) 
print(arr)
# Out:
# ['Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook']

# %% [markdown]
# # Challenge 2: Count Commits

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/commits'
parametro = {'since': '2020-10-26T00:00:00Z','until': '2020-11-01T23:59:59Z' }

response = requests.get(url, headers={"Authorization": token}, params=parametro)
response.json()
# Out:
# [{'sha': '56c1aa10c26d062c4b19848da442f9d5cc0e9f30',
#   'node_id': 'MDY6Q29tbWl0MzA0MjQ4NTM5OjU2YzFhYTEwYzI2ZDA2MmM0YjE5ODQ4ZGE0NDJmOWQ1Y2MwZTlmMzA=',
#   'commit': {'author': {'name': 'ironhack-datalabs',
#     'email': 'agalvezcorell@gmail.com',
#     'date': '2020-10-30T09:29:13Z'},
#    'committer': {'name': 'ironhack-datalabs',
#     'email': 'agalvezcorell@gmail.com',
#     'date': '2020-10-30T09:29:13Z'},
#    'message': 'txt myproject',
#    'tree': {'sha': 'bdbe22c3904a29d980684618bcff2b910af816d5',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/trees/bdbe22c3904a29d980684618bcff2b910af816d5'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/commits/56c1aa10c26d062c4b19848da442f9d5cc0e9f30',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
count=0
for _ in response.json():
    count+=1
print(count)
# Out:
# 11

# %% [markdown]
# # Challenge 3: Hidden Cold Joke

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'
response = requests.get(url, headers={"Authorization": token})
response.json()
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  {'name': '15024',
#   'path': '15024',
#   'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'size': 0,
# ...

# %%
arr_sha=[]
for i in response.json():
    arr_sha.append(i['sha'])
arr_sha
# Out:
# ['e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#  '2945e51c87ad5da893c954afcf092f06343bbb7d',
#  '5af6f2a7287e4191f39e55693fc1e9c8918d1d3a',
#  '9c49f920aa4d9433fa99a5824128f0e6b90ec5f2',
#  'c488d7f64088c852e22067d48fdc64ee3670f3ba',
#  '30193d9cf62b07bcbb6366513ff03596861f2d29',
#  '22fc3d5c2db80822c351edb2248f3491c8ebda86',
#  '6a4a88cd9084110c8646c3cfd84dfe96b300a4a7',
#  'c7001604cdadc2fe7b82e0f6996690718cac6941',
#  'f84882ad7560fd2b8c6a0867bc707ce9009ef288',
#  '46bc658c09589d9023246b00e848ce97d30d4989',
#  'e47a7a35a19f80694587330c57d94e28d3b4c054',
#  '636fa555a2ee752759144a268fd860feb2b6fd2d',
#  'a00a8148a88287508a867616d7063786d3d5d4ff',
#  '28d70fba98bfacfaa5e5544b2eff6b61c9e8f57b',
#  '88b159d6f73378e6968bb35ccfd8e3ad0cc462d2',
#  '0230fa6fa1ccf49ab976fbbfc9eb838094779785',
#  'ed2f90be6835e7e74c283aedba1942b788754d32',
#  'a5d9391003b67cecf3c336398ec38cfa75a689b7',
#  'd1a654c5811f52ec8a101652b0a04367644eab99',
#  'f294d2a0e55a4bab12625a7f709b44450a5e4648',
# ...

# %%
#Esto es una prueba para un solo sha (los pasos que debo seguir para obtener el nombre del archivo)
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d'
response = requests.get(url, headers={"Authorization": token})
x=response.json()
u=x['tree']
u2=(u[0])
print(u2)
# Out:
# {'path': '.0006.scavengerhunt', 'mode': '100644', 'type': 'blob', 'sha': '1c9064284a24b3486015eafdb391b141c27ada2b', 'size': 3, 'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b'}

# %%
#copio el nombre y el url
path={u2['path']:u2['url']}
path
# Out:
# {'.0006.scavengerhunt': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b'}

# %%
#del url extraigo el content
response = requests.get(path['.0006.scavengerhunt'], headers={"Authorization": token})
x=response.json()
p=x['content']
p
# Out:
# 'b2YK\n'

# %%
#decodifico el contenido
d=base64.b64decode(p)
d
# Out:
# b'of\n'

# %%
#Al intentar aplicar lo anterior usando un for para poder recorrer todos los sha obtengo el error "TimeoutError"
arr_1=[]
for i in arr_sha:
    print(1)
    url = f'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/{i}'
    response = requests.get(url, headers={"Authorization": token})
    x=response.json()
    arr_1.append(x)
# Out:
# 1
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...

# %%
arr_2=[]
for i in arr_1:
    u=i['tree']
    arr_2.append(u)

# %%
arr_3=[]
for i in arr_2:
    u2=(i[0])
    arr_3.append(u2)

# %%
arr_path=[]
for i in arr_3:
    arr_path.append(i['path'])
    arr_url.append(i['url'])
print(arr_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-22d4d114e13f> in <module>
#       2 path_url={}
#       3 for i in arr_3:
# ----> 4     path_url.update(i['path'],i['url'])
#       5 print(path_url)
#       6
#
# TypeError: update expected at most 1 argument, got 2

# %%
path_url = dict.fromkeys(arr_path)
for i in arr_url:
    versiones = dict.fromkeys(i)
print(versiones)
# Out:
# {'path3': None, 'url4': None}
