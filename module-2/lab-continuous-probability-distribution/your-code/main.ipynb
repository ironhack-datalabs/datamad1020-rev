# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import uniform

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.03840517 2.06190823 2.43972854 2.11336744 2.16791561 2.92728665
#  2.39122654 2.1972649  2.45402753 2.72259038]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %% [markdown]
# ###### Apartado a)

# %%
x = uniform.rvs(size=100)
a = 10
b = 15
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [12.39352772 14.58875077 12.70869501 13.06071998 12.66199946 12.59795736
#  14.14589433 14.40877756 10.01022182 12.26108444 12.40046516 11.78682601
#  12.44796406 10.88195729 14.37379397 14.91167416 14.14936862 12.14317192
#  12.26089747 10.53047282 14.39045102 12.19514634 12.69085782 10.54670014
#  10.14010939 13.31767001 12.8382017  13.59499879 10.17871853 13.68429146
#  10.60488241 11.01644771 11.37285146 11.96823031 10.69288812 12.51867368
#  11.9541145  12.34567683 10.99955781 11.71393138 13.20202753 11.89217507
#  13.42725954 14.87299815 12.10335009 14.64398301 11.92687893 13.12753761
#  11.3591901  10.70343167 13.10281343 11.89672816 12.63974174 11.65365794
#  14.24020247 12.7099562  11.38777182 14.81037787 12.39648352 11.79426238
#  10.15620869 10.89874412 13.90075428 14.15502734 14.78163768 11.79488638
#  14.54465548 11.41760294 10.97719016 11.05013072 12.88140935 10.84123633
#  10.93099974 14.26557779 13.72472273 13.03594324 10.87713091 13.21607631
#  11.05851412 11.71632588 12.68348451 13.92700587 11.38153209 14.59378431
#  11.25934219 12.42876808 10.08034095 11.66371251 13.76545439 12.46861463
#  11.5992537  12.75661479 10.5556782  10.42552763 10.31411524 14.09724419
#  11.47810767 10.7802442  12.60751178 14.12850348]

# %%
count_results = {x: list(randoms).count(x) for x in randoms}

# %%
#plt.hist(y = randoms,
         #x = count_results , bins=10, density=True)

plt.hist(randoms,
         bins=10, density=True)
plt.title('Uniform Distribution A', size=10)
plt.xlabel('values')
plt.ylabel('count')
# plt.ylim(0, 100)
plt.show()

# %% [markdown]
# ###### Apartado b)

# %%
x = uniform.rvs(size=1000)
#  36.235711   29.01240641 25.51571148 42.35027574 50.46512644 24.80263447
#  49.00923331 53.32977979 10.15525742 44.81130162 18.31640665 16.51144251
#  10.55048862 50.14403771 40.85454202 20.03289916 21.5124176  40.07500875
#  35.48939552 12.15515767 42.15036979 47.80906994 15.47598922 26.82166139
#  39.00825487 46.21860208 37.61082353 53.22887526 19.03418029 18.74694881
#  29.8006512  35.88555679 14.01162676 39.19895844 52.28761936 24.9776378
#  16.26450298 46.92545068 21.5484386  52.70419622 42.59301613 23.66634004
#  15.80145287 17.9219275  55.83851996 23.58576405 51.82288594 31.57564109
#  18.56553126 27.5003477  48.89992589 17.12645891 36.00504334 16.99701043
#  33.2274503  48.08523603 50.30339231 43.21916381 48.40503476 45.3574505
#  34.34153872 44.89529814 17.9752889  30.09328731]

# %%
count_results = {x: list(randoms_2).count(x) for x in randoms_2}

# %%
plt.hist(count_results, bins=10, density=True)

plt.title('Uniform Distribution B', size=10)
plt.xlabel('values')
plt.ylabel('count')

plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# La diferencia de ambas gráficas esta en que la primera gáfica le hemos dicho que tome valores random del 10 al 15 y por lo tanto los 100 nº que genera se encuentran en la parte inferior de la grafica ya que no salen del rango 10-15.
# Y la segunda, a diferencia de la primera grafica, toma valores en un rango más amplio (del 10 al 60) además de que le hemos dicho que sque 1000 valores por lo que va a ver valores mucho más altos y por eso se ve el histograma mucho mas uniforme en la parte superior de la grafica.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here

# %% [markdown]
# 3. Combined MPG

# %%
# your code here

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
