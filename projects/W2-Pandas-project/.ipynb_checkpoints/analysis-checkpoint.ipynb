# %% [markdown]
# # HYPOTHESIS :
# ## USA suffers the most shark attacks because they have a greater density of white sharks in their coasts which are known to be the most dangerous shark species. I also predict that most attacks will have happened to men since they are more into water sports than women, specially surfing.

# %% [markdown]
# In order to test this hypothesiis, I´m going to use a data sheet downloaded from kaggle about shark attacks that have happenen all around the world in recent years..

# %% [markdown]
# In order to get straight to the point, let´s start by providing a list of the countries that suffer the most shark attacks:

# %%
# Countries with the most shark accidents

# %% [markdown]
# ![countries.jpg](attachment:countries.jpg)

# %% [markdown]
# As the data proves, my hypothesis seems to be holding up for now. I was right when I stated that USA suffered the most shark attacks in the world. Not surprisingly, they "win" by far...

# %% [markdown]
# Secondly, I will now show a graph that divides shark attacks by gender:

# %%
# Which gender dies the most

# %% [markdown]
# ![gender.jpg](attachment:gender.jpg)

# %% [markdown]
# As we can see, men seem to die more oftenly in the sea because of shark attacks than women. My believe is that men fancy more water sports in the sea than women.

# %% [markdown]
# Next, we are going to take a look at how these accidents are happening. What is the biggest cause of shark attacks:

# %%
# Which activities cause more accidents

# %% [markdown]
# ![activities.jpg](attachment:activities.jpg)

# %% [markdown]
# Unfortunately for surfers... surfing seems to be a bit more dangerous than we all thought.

# %% [markdown]
# The following graph is a bit irrelevant to the hypothesis. I decided to take a moment to analyse how can USA be more affected by shark attacks while surfing than Australia, since Australia (and Hawaii) is known to be the place to go if you want to surf a lot. In my opinion it would make more sence that Australia was more affected by sharks while surfing than the US.

# %%
# Surfing accidents by country

# %% [markdown]
# ![surfing.jpg](attachment:surfing.jpg)

# %% [markdown]
# As shown, USA has the lead in surfing accidents. This makes me realise that the whole data set is biased by population differences. A lot more people live in the US than in Australia, in fact there is around x13 more people living in the US than in Australia and that explains this last result.

# %% [markdown]
# Now let´s take a look at "who" is to blame for most shark attacks!!

# %%
# What shark species is attacking the most

# %% [markdown]
# ![shark.jpg](attachment:shark.jpg)

# %% [markdown]
# Aha!! We found the biggest trouble maker!! As the hypothesis stated, it was very likely that most of the shark attacks were being caused by the famous white shark.

# %% [markdown]
# And finally, let's prove that white sharks attack the most in USA:

# %%
# Where is the white shark attacking the most

# %% [markdown]
# ![white.jpg](attachment:white.jpg)

# %% [markdown]
# Uups.. It seems like this last part of my hypothesis was WRONG! Australia has the biggest problem with white sharks along with South Africa. To my surprise, USA comes in third position. So we can conclude that South Africa, which was third in position for shark attacks, has the most attacks caused by the all-so-feared WHITE SHARK!!
#
# Key take away: "If you ever visit South Africa, go to see the giraffes and let the surfing experience be for other people..."
