# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# Answer all questions by drawing a graph. Then explain.

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# **0. Load seaborn dataset "tips"**

# %%
df_tips = sns.load_dataset("tips")

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# **1. What is the prefered day for eating?**

# %%
df_tips.groupby("day").total_bill.sum()
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %% [raw]
# si no he entendido mal la pregunta, el dia preferido para ir a comer sera el dia que el total de la cuenta sea mayor. Por eso he agrupado los dias de la semana y la suma del total de las cuentas cada uno de esos dias.

# %% [markdown]
# **2. What days of the week has more men than women payers?**

# %%
#df_titanic.groupby('sex').survived.sum()
#df_tips.groupby("sex").day.sum()
#df_tips[df_tips.sex=='Male'].day
#df_tips[df_tips.day==''].shape[0]
#df_tips[df_tips.day=='Male'].sex
df_tips.groupby("day").sex.value_counts()
# Out:
# day   sex
# Thur  Female    32
#       Male      30
# Fri   Male      10
#       Female     9
# Sat   Male      59
#       Female    28
# Sun   Male      58
#       Female    18
# Name: sex, dtype: int64

# %% [raw]
# En este apartado te preguntan que dias de la semana hay mas hombres que mujeres clientas, y con grupby he obtenido una tabla que me muestra el nnumero total tanto de hombres como de mujeres que van cada dia de la semana.

# %% [markdown]
# **3. Do you think bill amounts change considerably depending on smoking?**

# %%
df_tips.groupby("smoker").total_bill.sum()
# Out:
# smoker
# Yes    1930.34
# No     2897.43
# Name: total_bill, dtype: float64

# %% [raw]
# De esta manera represento en una tabla los dos tipos de clientes que hay (si son fumadores o no) y la suma total de las cuentas habiendo fumadores y no fumadores.

# %% [markdown]
# **4. Is tip correlated to total_bill? Draw a scatter plot**

# %%
sns.scatterplot(data=df_tips, x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **BONUS**: Draw a graph of your choice with 2 numerical variables and 2 categorical variable (HINT: use `hue` and `style`). Do you find it useful?
