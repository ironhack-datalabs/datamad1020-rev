# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import uniform
import pandas as pd

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.55162268 2.16629547 2.54270932 2.9681475  2.90563437 2.50440042
#  2.56662442 2.05777319 2.62180805 2.85239961]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %% [markdown]
# ###### Apartado a)

# %%
x = uniform.rvs(size=100)
a = 10
b = 15
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [13.99844776 12.46500506 13.36008345 12.72175743 14.12498081 11.70679153
#  12.69349936 14.84460274 10.03809634 11.18390404 12.20287461 10.1343627
#  12.86218974 12.73771573 14.78771369 13.27349504 10.30412148 13.4378851
#  11.4293023  14.65195146 14.57415615 11.68304804 14.64560932 10.72481571
#  14.69309816 11.62435958 13.73298657 14.57999796 13.93373054 11.17433439
#  11.88544278 14.63047093 14.40046197 13.63525651 10.35908379 13.17087979
#  12.10375927 12.30601703 12.33055353 10.24830949 12.20411638 14.47095331
#  12.50097429 11.88439493 13.46799239 11.38546832 12.39211647 12.32021529
#  14.79941651 11.872665   13.45493247 14.15827022 10.13345551 13.09924767
#  14.83400393 10.89130737 12.64913486 14.17528405 12.69435723 13.22200768
#  13.12052054 11.89071913 10.58679508 14.01563329 11.47757141 10.10071484
#  13.57599286 13.53436498 14.67238793 10.80499729 11.55428989 14.67189413
#  12.55212368 12.36259769 14.73098463 12.74530079 13.37970686 13.51471171
# ...

# %%
count_results = {x: list(randoms).count(x) for x in randoms}

# %%
#plt.hist(y = randoms,
         #x = count_results , bins=10, density=True)

plt.hist(randoms,
         bins=10, density=True)
plt.title('Uniform Distribution A', size=10)
plt.xlabel('values')
plt.ylabel('count')
# plt.ylim(0, 100)
plt.show()

# %% [markdown]
# ###### Apartado b)

# %%
x = uniform.rvs(size=1000)
a = 10
b = 60
randoms_2  = a + (b-a)*x
print(randoms_2)
# Out:
# [13.11929665 31.08065531 30.85659786 41.1532776  43.68194188 16.09540459
#  55.3015266  31.29475955 17.85003113 50.73522535 40.15455327 23.24800873
#  24.68355401 29.47714538 16.08161631 44.29403369 29.15469858 25.85830161
#  23.10176944 33.0678707  37.12115843 32.42964163 21.52368873 42.36562425
#  59.73307894 45.92303737 13.8577527  32.40753389 36.93572275 59.8966387
#  13.25111241 38.60330411 40.26402973 12.06994329 50.87348053 31.92462288
#  16.88279769 16.40537947 47.82625256 37.44820439 52.63851647 54.62200506
#  47.49110654 16.59356865 43.05278176 20.08507828 19.70027087 58.02376337
#  53.42810527 58.45197512 32.02571589 14.08858338 15.56675417 31.10145599
#  13.81028035 54.26625865 30.99572755 41.48557243 36.19111237 50.25608491
#  11.79129715 21.99244733 32.44058249 15.40898761 40.66864575 36.85182874
#  17.41462884 28.17859704 31.40747251 48.42843028 55.89759105 29.73874045
#  11.39263644 14.00123512 20.404612   42.92009175 56.33060148 11.50044871
# ...

# %%
count_results = {x: list(randoms_2).count(x) for x in randoms_2}

# %%
plt.hist(count_results, bins=10, density=True)

plt.title('Uniform Distribution B', size=10)
plt.xlabel('values')
plt.ylabel('count')

plt.show()

# %%
# Juntamos ambas graficas para su comparacion:

fig, (ax1, ax2) = plt.subplots(1, 2, sharey = True)
sns.histplot(x = randoms, bins = 'auto', ax = ax1)
sns.histplot(x = randoms_2, bins = 'auto', ax = ax2)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# La diferencia de ambas gráficas esta en que la primera gáfica le hemos dicho que tome valores random del 10 al 15 y por lo tanto los 100 nº que genera se encuentran en la parte inferior de la grafica ya que no salen del rango 10-15.
# Y la segunda, a diferencia de la primera grafica, toma valores en un rango más amplio (del 10 al 60) además de que le hemos dicho que sque 1000 valores por lo que va a ver valores mucho más altos y por eso se ve el histograma mucho mas uniforme en la parte superior de la grafica.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %% [markdown]
# ##### Gráfica A

# %%
normal_A = norm(loc=10, scale=1)

# %%
normal_A.mean()
# Out:
# 10.0

# %%
normal_A.std()
# Out:
# 1.0

# %%
sample_A = normal_A.rvs(size=1000)

# %%
sns.histplot(sample_A, element="step")
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ##### Gráfica B

# %%
normal_B = norm(loc=10, scale=50)

# %%
sample_B = normal_B.rvs(size=1000)

# %%
sns.histplot(sample_B, element="step")
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Juntamos ambas graficas para poder compararlas:

fig, (ax1, ax2) = plt.subplots(1, 2, sharey = True)
sns.histplot(x = sample_A, bins = 'auto', ax = ax1)
sns.histplot(x = sample_B, bins = 'auto', ax = ax2)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# Ambas graficas se parecen mucho visualemnte, pero para encontrar sus diferencias nos tenemos que fijar en el eje x.
# Como podemos ver, cada grafica se distribuye en un rango completamente diferente, una de ellas toma hasta nº negativos y la otra no...
# Esto significa que aunque ambas gráficas estén pintadas con la misma media aritmétrica, el standar deviation es quien hace que sean muy diferentes.
# El standar deviation es la separación que existe entre cualquier valor de la serie y la media aritmética de todos los datos de dicha serie.
#     - Teniendo en una grafica std=1 (la separacion es mucho menor con respecto a la media)
#     - y teniendo la otra con std=50 (la separacion es mucho mayor con respecto a la media)

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:

# %%
# Importamos primero el csv
vehicles = pd.read_csv('../your-code/vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# 1. Fuel Barrels/Year

# %%
fuel = sns.histplot(x = vehicles["Fuel Barrels/Year"])

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
sns.histplot(x = vehicles["CO2 Emission Grams/Mile"])
# Out:
# <AxesSubplot:xlabel='CO2 Emission Grams/Mile', ylabel='Count'>

# %% [markdown]
# 3. Combined MPG

# %%
sns.histplot(x = vehicles["Combined MPG"])
# Out:
# <AxesSubplot:xlabel='Combined MPG', ylabel='Count'>

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %% [markdown]
# Diría que la primera y la segunda gráfica son las más parecidas en cuanto a su distribucion normal ya que en el eje x podemos ver entre que nº se comprenden cada visualizacion y por tanto parecen que tienen una desviacion tipica mucho más similar.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
from scipy.stats import expon
import numpy

# %% [markdown]
# ##### Gráfica A

# %%
'''
OTRA PRUEBA HABER SI ME SALIA LA GRAFICA DE OTRA MANERA....pero no....

import numpy as np 
import matplotlib.pyplot as plt 
  
# Using exponential() method 
gfg = np.random.exponential(10, 10) 
  
plt.hist(gfg, bins = 100, density = True)
# plt.ylim(0, 70)
plt.show()

'''

# %%
expo_A = numpy.random.exponential(10, 10)
sns.histplot(x = expo_A, bins = 100)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# #### Gráfica B

# %%
expo_B = numpy.random.exponential(10, 100)
sns.histplot(x = expo_A, bins = 100)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Juntamos las gráficas para compararlas: 

fig, (ax1, ax2) = plt.subplots(1, 2, sharey = True)
sns.histplot(x = expo_A, bins = 100, ax = ax1)
sns.histplot(x = expo_B, bins = 100, ax = ax2)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ##### DUDA!!!!!
# - No entiendo porque al hacer las graficas por separado me salen de esa manera y al unirlas ya me salen con forma de grafic exponencial.
# - Ademas la primera grágixa (la A) al juntarlas tampoco me sale como me deberia de salir.... y hago exactamente lo mismo en la A que en l B....

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
time = expon(scale=10)
time.mean()
# Out:
# 10.0

# %%
'''
Para calcular una probabilidad menor o mayor a la media utilizamos la : 
  # Cumulative distribution function
  #.cdf is the cumulative distribution function
  #.cdf(x) tells us the probability of 𝑋<𝑥
    
Dibujando en un papel mi grafico, señalando la media en en centro de la grafica y observando donde estaba el 15 es mucho más facil ver y entender
cuando tienes que restar a uno la cdf o cuando no.
'''

time.cdf(15)
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# es la parte mas pequeña de nuestra grafica y por ello tenemos que restar el cdf a 1 para poder conseguir la probabilidad de ese trocito.

1 - time.cdf(15)
# Out:
# 0.2231301601484298
