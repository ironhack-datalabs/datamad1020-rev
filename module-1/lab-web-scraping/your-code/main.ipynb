# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some web scraping exercises to practice your scraping skills using `requests` and `Beautiful Soup`.
#
# **Tips:**
#
# - Check the [response status code](https://http.cat/) for each request to ensure you have obtained the intended content.
# - Look at the HTML code in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.
# - Check out the css selectors.

# %% [markdown]
# ### Useful Resources
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### First of all, gathering our tools.

# %%
from IPython.core.display import display, HTML

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import regex

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
response =requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-K+2SY5WIogVf/13vJ9BeX4zVI7sQjuctb6bSHvfTYr6EjQSM0YWKa9kCnnlZYAbPazx/aK3+IfeU2Q8m0y3ePA==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-2bed92639588a2055fff5def27d05e5f.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-coVq0vBxd4jhdJQktTbvvxOMjCq7cujGRd6AY86J5bqRiWgFr5wNtVhIK
# ...

# %%
soup = BeautifulSoup(response.content)

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below (with different names):
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
trending_authors = soup.find_all("h1", class_="h3 lh-condensed")

# %%
len(trending_authors)
# Out:
# 25

# %%
trending_authors[0]
# Out:
# <h1 class="h3 lh-condensed">
# <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":18496796,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="e5854759020e8dbf93d6da1a17115098822e6f09f42a6aa9bd29f8d2674769f2" href="/mpariente">
#             Pariente Manuel
# </a> </h1>

# %%
authors = soup.select('h1.h3 a[href]')

# %%
print(authors[0].text)
# Out:
#             Pariente Manuel

# %%
autores = []

for i in authors:
    autores.append((i.text).rstrip().lstrip())

# %%
autores
# Out:
# ['Pariente Manuel',
#  'Arvid Norberg',
#  'Lorenzo Fontana',
#  'Jonah Williams',
#  'Vadim Dalecky',
#  'Ariel Mashraki',
#  'Filip Skokan',
#  'Seth Michael Larson',
#  'Mike Hardy',
#  'Philip Rideout',
#  'Fangrui Song',
#  'Sam Clegg',
#  'Gal Schlezinger',
#  'Jeremy Rose',
#  'Amanpreet Singh',
#  'Gleb Bahmutov',
#  'Magnus Edenhill',
#  'Jed Watson',
#  'Shougo',
#  'Mike Penz',
#  'Marcin Rataj',
#  'Kyle Spearrin',
#  'Sebastián Ramírez',
#  'Miguel Ángel Durán',
#  'Jonathan Rochkind']

# %%
mote = soup.select('p.f4 a[href]') #centrase en los tabs y no todo lo que está escrito#
                                   #también ir bajando los niveles

# %%
usuario = []

for i in mote:
    usuario.append((i.text).rstrip().lstrip())

# %%
usuario
# Out:
# ['mpariente',
#  'arvidn',
#  'fntlnz',
#  'jonahwilliams',
#  'streamich',
#  'a8m',
#  'panva',
#  'sethmlarson',
#  'mikehardy',
#  'prideout',
#  'MaskRay',
#  'sbc100',
#  'Schniz',
#  'nornagon',
#  'apsdehal',
#  'bahmutov',
#  'edenhill',
#  'JedWatson',
#  'Shougo',
#  'mikepenz',
#  'lidel',
#  'kspearrin',
#  'tiangolo',
#  'midudev',
#  'jrochkind']

# %%
total = [(i + '  '+ j) for (i,j) in zip(autores, usuario)]

# %%
total
# Out:
# ['Pariente Manuel  mpariente',
#  'Arvid Norberg  arvidn',
#  'Lorenzo Fontana  fntlnz',
#  'Jonah Williams  jonahwilliams',
#  'Vadim Dalecky  streamich',
#  'Ariel Mashraki  a8m',
#  'Filip Skokan  panva',
#  'Seth Michael Larson  sethmlarson',
#  'Mike Hardy  mikehardy',
#  'Philip Rideout  prideout',
#  'Fangrui Song  MaskRay',
#  'Sam Clegg  sbc100',
#  'Gal Schlezinger  Schniz',
#  'Jeremy Rose  nornagon',
#  'Amanpreet Singh  apsdehal',
#  'Gleb Bahmutov  bahmutov',
#  'Magnus Edenhill  edenhill',
#  'Jed Watson  JedWatson',
#  'Shougo  Shougo',
#  'Mike Penz  mikepenz',
#  'Marcin Rataj  lidel',
#  'Kyle Spearrin  kspearrin',
#  'Sebastián Ramírez  tiangolo',
#  'Miguel Ángel Durán  midudev',
#  'Jonathan Rochkind  jrochkind']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
response = requests.get(url)

# %%
response.status_code

# %%
soup = BeautifulSoup(response.content)

# %%
mote = soup.select('h1 a')

# %%
repos = soup.select('h1.h3 a[href]')

# %%
repositorio = [i.text for i in repos]

# %%
def limpiar(x):

    lista = []

    for i in x:
        lista.append((i.text).strip())

        df = pd.DataFrame(lista)
        
    return df

# %%
repositorios = limpiar(repos)

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
response = requests.get(url)

# %%
display(HTML¡¡¡¡)

# %%
response.status_code

# %%
soup = BeautifulSoup(response.content)

# %%
soup

# %%
img = soup.find_all('img')

# %%
def img(a):
    
    '''
    En esta función pido que me encuentre todos los tags de 'img', para despues encontrar dentro de cada objeto el src(source)
    que es el link de la imagen. Por último, itero por la lista con los link y saco los que acaben por jpg, que son las 
    imágenes que me interesan (así descarto las png). 
    
    '''
    
    x = a.find_all('img')
    
    
    imagen = [i['src'] for i in x]

        
    imagen = [i for i in image_src if i.endswith('jpg')]

        
    return imagen

# %%
img(soup)

# %% [markdown]
# #### Otra manera de hacerlo utilizando la libreria re (regular expressions)

# %%
import re

images = soup.find_all('img', {'src':re.compile('.jpg')})

imagenes = []

for image in images: 
    imagenes.append(image['src']+'\n')

# %% [markdown]
# #### Retrieve all links to pages on Wikipedia that refer to some kind of Python.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content)

# %%
repos = soup.select('h1.h3 a[href]')

# %%
links = soup.select_all('ul.li')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-6ca44666735a> in <module>
# ----> 1 links = soup.select_all('ul.li')
#
# TypeError: 'NoneType' object is not callable

# %%
links
# Out:
# [<ul><li><a class="mw-redirect" href="/wiki/Pythons" title="Pythons">Pythons</a> or Pythonidae, a family of nonvenomous snakes found in Africa, Asia, and Australia
#  <ul><li><a href="/wiki/Python_(genus)" title="Python (genus)"><i>Python</i> (genus)</a>, a genus of nonvenomous Pythonidae found in Africa and Asia</li></ul></li></ul>,
#  <ul><li><a href="/wiki/Python_(genus)" title="Python (genus)"><i>Python</i> (genus)</a>, a genus of nonvenomous Pythonidae found in Africa and Asia</li></ul>,
#  <ul>
#  <li class="toclevel-1 tocsection-1"><a href="#Computing"><span class="tocnumber">1</span> <span class="toctext">Computing</span></a></li>
#  <li class="toclevel-1 tocsection-2"><a href="#People"><span class="tocnumber">2</span> <span class="toctext">People</span></a></li>
#  <li class="toclevel-1 tocsection-3"><a href="#Roller_coasters"><span class="tocnumber">3</span> <span class="toctext">Roller coasters</span></a></li>
# ...

# %%
#mw-content-text > div.mw-parser-output > ul:nth-child(7) > li:nth-child(1) > a

# %%
links.selec_all('li')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-1ae6f541611e> in <module>
# ----> 1 links.selec_all('li')
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2158     def __getattr__(self, key):
#    2159         """Raise a helpful exception to explain a common code fix."""
# -> 2160         raise AttributeError(
#    2161             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2162         )
#
# AttributeError: ResultSet object has no attribute 'selec_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
web_links = [i.find('a')['href'] for i in links ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-f2c36f0c5b52> in <module>
# ----> 1 web_links = [i.find('a')['href'] for i in links ]
#
# <ipython-input-84-f2c36f0c5b52> in <listcomp>(.0)
# ----> 1 web_links = [i.find('a')['href'] for i in links ]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
prueba = soup.select('ul li[href]')

# %%
prueba
# Out:
# []

# %%
for i in links:
    print(i["href"])
# Out:
# #start-of-content
# https://github.com/
# /join?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2Ftrending%2Fdevelopers&source=header
# /features
# /features/code-review/
# /features/project-management/
# /features/integrations
# /features/actions
# /features/packages
# /features/security
# /features#team-management
# /features#hosting
# /mobile
# /customer-stories
# /security
# /team
# /enterprise
# /explore
# /topics
# /collections
# /trending
# https://lab.github.com/
# https://opensource.guide
# https://github.com/events
# https://github.community
# https://education.github.com
# https://stars.github.com
# /marketplace
# /pricing
# /pricing#feature-comparison
# https://enterprise.github.com/contact
# /nonprofit
# https://education.github.com
#
#
#
# /login?return_to=%2Ftrending%2Fdevelopers
# /join?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2Ftrending%2Fdevelopers&source=header
# /explore
# /topics
# /trending
# /collections
# /events
# /sponsors/community
# ...

# %%
#mw-content-text > div.mw-parser-output > ul:nth-child(7) > li:nth-child(1) > a

# %%
links
# Out:
# [<a class="px-2 py-4 bg-blue text-white show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>,
#  <a aria-label="Homepage" class="mr-4" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %% [markdown]
# ### Stepping up the game

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current

# %%
def weather(city):
    pass

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'
