# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
# from pymongo import MongoClient
# client = MongoClient("")

# %%
# !pip3 install pymongo
# Out:
# ...
#      |████████████████████████████████| 379 kB 3.9 MB/s eta 0:00:01
# ...

# %%
from pymongo import MongoClient
import pandas as pd

# %%
conn = MongoClient('localhost:27017')

# %%
# choose database to work with
db = conn.get_database('ironhack')

# %%
collection = db.get_collection('companies')

# %%
dataset = collection.find()

# %%
type(dataset)
# Out:
# pymongo.cursor.Cursor

# %%
df = pd.DataFrame(dataset)

# %%
df.head()
# Out:
#                         _id       name permalink  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint      abc2
# 1  52cdef7c4bab8bd675297d8b  AdventNet      abc3
# 2  52cdef7c4bab8bd675297d8c       Zoho      abc4
# 3  52cdef7c4bab8bd675297d8d       Digg      digg
# 4  52cdef7c4bab8bd675297d8e   Facebook  facebook
#
#                                 crunchbase_url             homepage_url  \
# 0   http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 1  http://www.crunchbase.com/company/adventnet     http://adventnet.com
# 2       http://www.crunchbase.com/company/zoho          http://zoho.com
# 3       http://www.crunchbase.com/company/digg      http://www.digg.com
# 4   http://www.crunchbase.com/company/facebook      http://facebook.com
#
#                       blog_url                      blog_feed_url  \
# 0  http://digitalquarters.net/   http://digitalquarters.net/feed/
# 1
# 2       http://blogs.zoho.com/         http://blogs.zoho.com/feed
# ...

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
# Your Code
collection.find({'name': 'Babelgum'}, {'name': 1})

# %%
list(_)
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297da0'), 'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
# Your Code
c = collection

# %%
c_1 = c.find_one({"number_of_employees": {"$gt": 5000}})

# %%
list(c.find({'number_of_employees': {'$gt': 5000}}, {'name': 1, 'number_of_employees': 1}).sort('number_of_employees', -1).limit(5))
# Out:
# [{'_id': ObjectId('52cdef7d4bab8bd67529941a'),
#   'name': 'Siemens',
#   'number_of_employees': 405000},
#  {'_id': ObjectId('52cdef7c4bab8bd67529856a'),
#   'name': 'IBM',
#   'number_of_employees': 388000},
#  {'_id': ObjectId('52cdef7d4bab8bd675299d33'),
#   'name': 'Toyota',
#   'number_of_employees': 320000},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e89'),
#   'name': 'PayPal',
#   'number_of_employees': 300000},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b0fe'),
#   'name': 'Nippon Telegraph and Telephone Corporation',
#   'number_of_employees': 227000}]

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
pd.DataFrame(c.find({'founded_year': {"$in": [2000, 2001, 2002, 2004, 2005]}}, {'name': 1, 'founded_year': 1}).limit(5))
# Out:
#                         _id       name  founded_year
# 0  52cdef7c4bab8bd675297d8a   Wetpaint          2005
# 1  52cdef7c4bab8bd675297d8c       Zoho          2005
# 2  52cdef7c4bab8bd675297d8d       Digg          2004
# 3  52cdef7c4bab8bd675297d8e   Facebook          2004
# 4  52cdef7c4bab8bd675297d8f  Omnidrive          2005

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
# Your Code
pd.DataFrame(c.find(
    {"$and": [
        {'ipo.valuation_amount': {'$gt': 100000000}},
        {'founded_year': {"$lt": 2010}}
    ]},
    {"name": 1, "ipo.valuation_amount": 1}
))
# Out:
#                          _id                  name  \
# 0   52cdef7c4bab8bd675297d8e              Facebook
# 1   52cdef7c4bab8bd675297d94               Twitter
# 2   52cdef7c4bab8bd675297de0                  Yelp
# 3   52cdef7c4bab8bd675297e0c              LinkedIn
# 4   52cdef7c4bab8bd675297e7a                Amazon
# 5   52cdef7c4bab8bd675297e81            Brightcove
# 6   52cdef7c4bab8bd675297ee5           KIT digital
# 7   52cdef7c4bab8bd675297f15               Nielsen
# 8   52cdef7c4bab8bd675297f36             OpenTable
# 9   52cdef7c4bab8bd675297f42        ChannelAdvisor
# 10  52cdef7c4bab8bd675297f95         Jive Software
# 11  52cdef7c4bab8bd67529800c                Zillow
# 12  52cdef7c4bab8bd67529805d                   Wix
# 13  52cdef7c4bab8bd675298112            Shutterfly
# 14  52cdef7c4bab8bd6752981a7           TripAdvisor
# 15  52cdef7c4bab8bd67529823b            Salesforce
# 16  52cdef7c4bab8bd6752982f6              HomeAway
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
# Your Code
list(c.find(
    {"$and": [
        {'number_of_employees': {'$lt': 1000}},
        {'founded_year': {"$lt": 2005}}
    ]},
    {"name": 1, "number_of_employees": 1}
).sort('number_of_employees', -1).limit(10))
# Out:
# [{'_id': ObjectId('52cdef7d4bab8bd675298933'),
#   'name': 'Infinera Corporation',
#   'number_of_employees': 974},
#  {'_id': ObjectId('52cdef7e4bab8bd67529ac95'),
#   'name': 'NorthPoint Communications Group',
#   'number_of_employees': 948},
#  {'_id': ObjectId('52cdef7f4bab8bd67529be17'),
#   'name': '888 Holdings',
#   'number_of_employees': 931},
#  {'_id': ObjectId('52cdef7c4bab8bd6752986a2'),
#   'name': 'Forrester Research',
#   'number_of_employees': 903},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b21b'),
#   'name': 'Webmetrics',
#   'number_of_employees': 900},
#  {'_id': ObjectId('52cdef7e4bab8bd67529af6d'),
#   'name': 'SonicWALL',
#   'number_of_employees': 900},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b3bd'),
#   'name': 'Cornerstone OnDemand',
#   'number_of_employees': 881},
#  {'_id': ObjectId('52cdef7c4bab8bd67529857e'),
#   'name': 'Buongiorno',
#   'number_of_employees': 800},
#  {'_id': ObjectId('52cdef7c4bab8bd6752985c5'),
#   'name': 'Cvent',
# ...

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
# Your Code
pd.DataFrame(c.find({"partners": {'$exists': False}}))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
# Your Code - question changed to All the companies whose name contains the substring "hola".
pd.DataFrame(c.find({'name' : {'$regex' : ".*hola.*"}}))
# Out:
#                         _id                  name             permalink  \
# 0  52cdef7e4bab8bd67529acc2        Ethan Nicholas        ethan-nicholas
# 1  52cdef7e4bab8bd67529b44a      Scholastic Books      scholastic-books
# 2  52cdef7e4bab8bd67529bce2  Mobile Media Scholar  mobile-media-scholar
#
#                                       crunchbase_url  \
# 0   http://www.crunchbase.com/company/ethan-nicholas
# 1  http://www.crunchbase.com/company/scholastic-b...
# 2  http://www.crunchbase.com/company/mobile-media...
#
#                           homepage_url blog_url blog_feed_url  \
# 0  http://www.ethannicholas.com/iShoot
# 1                                 None     None          None
# 2                                 None     None          None
#
#   twitter_username category_code number_of_employees  ... investments  \
# 0             None        mobile                None  ...          []
# 1             None          None                None  ...          []
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
# Your Code
pd.DataFrame(c.find(
    {"$and": [
        {'number_of_employees': {'$gt': 100}},
        {'number_of_employees': {'$lt': 1000}}
    ]},
    {'name': 1, 'number_of_employees': 1}
))
# Out:
#                           _id                   name  number_of_employees
# 0    52cdef7c4bab8bd675297d8b              AdventNet                  600
# 1    52cdef7c4bab8bd675297da7                AddThis                  120
# 2    52cdef7c4bab8bd675297da8                  OpenX                  305
# 3    52cdef7c4bab8bd675297db5               LifeLock                  644
# 4    52cdef7c4bab8bd675297dbb                  Jajah                  110
# ..                        ...                    ...                  ...
# 748  52cdef7f4bab8bd67529c6ac   Inventa Technologies                  207
# 749  52cdef7f4bab8bd67529c6d1  UOL (Universo Online)                  500
# 750  52cdef7f4bab8bd67529c6e6      OfficialVirtualDJ                  102
# 751  52cdef7f4bab8bd67529c6f1          Willdan Group                  385
# 752  52cdef7f4bab8bd67529c6f3                   QSGI                  164
#
# [753 rows x 3 columns]

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
# Your Code - Question changed to: Give a dictionary similar to {"CocaCola": 1000, "Pepsi": 900} with the top 10 companies regarding IPO price.
pd.DataFrame(c.find({'ipo.valuation_amount': {'$exists' :True}}).sort ('ipo.valuation_amount',-1).limit(11))
# Out:
#                          _id             name        permalink  \
# 0   52cdef7e4bab8bd67529a8b4             GREE             gree
# 1   52cdef7c4bab8bd675297d8e         Facebook         facebook
# 2   52cdef7c4bab8bd675297e7a           Amazon           amazon
# 3   52cdef7c4bab8bd675297d94          Twitter          twitter
# 4   52cdef7d4bab8bd675299d5d          Groupon          groupon
# 5   52cdef7c4bab8bd675298674          Tencent          tencent
# 6   52cdef7e4bab8bd67529b996  Western Digital  western-digital
# 7   52cdef7c4bab8bd675297e0c         LinkedIn         linkedin
# 8   52cdef7c4bab8bd67529859a     BMC Software     bmc-software
# 9   52cdef7c4bab8bd675298527        Rackspace        rackspace
# 10  52cdef7c4bab8bd675298760            Baidu            baidu
#
#                                        crunchbase_url  \
# 0              http://www.crunchbase.com/company/gree
# 1          http://www.crunchbase.com/company/facebook
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
# Your Code
pd.DataFrame(c.find().sort('number_of_employees', -1).limit(11))
# Out:
#                          _id                                        name  \
# 0   52cdef7d4bab8bd67529941a                                     Siemens
# 1   52cdef7c4bab8bd67529856a                                         IBM
# 2   52cdef7d4bab8bd675299d33                                      Toyota
# 3   52cdef7c4bab8bd675297e89                                      PayPal
# 4   52cdef7e4bab8bd67529b0fe  Nippon Telegraph and Telephone Corporation
# 5   52cdef7d4bab8bd675298aa4                         Samsung Electronics
# 6   52cdef7d4bab8bd675298b99                                   Accenture
# 7   52cdef7e4bab8bd67529a657                   Tata Consultancy Services
# 8   52cdef7e4bab8bd67529aa51                   Flextronics International
# 9   52cdef7d4bab8bd675299156                                     Safeway
# 10  52cdef7c4bab8bd675297e6f                                        Sony
#
#                                      permalink  \
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
# Your Code
pd.DataFrame(c.find({'founded_month': {"$in": [6, 7, 8, 9, 10, 11, 12]}}, {'name': 1, 'founded_month': 1}).limit(1000))
# Out:
#                           _id         name  founded_month
# 0    52cdef7c4bab8bd675297d8a     Wetpaint             10
# 1    52cdef7c4bab8bd675297d8c         Zoho              9
# 2    52cdef7c4bab8bd675297d8d         Digg             10
# 3    52cdef7c4bab8bd675297d8f    Omnidrive             11
# 4    52cdef7c4bab8bd675297d90      Postini              6
# ..                        ...          ...            ...
# 995  52cdef7d4bab8bd675298d27     Openfilm             11
# 996  52cdef7d4bab8bd675298d29        uCubd              9
# 997  52cdef7d4bab8bd675298d2e      MyGreat              7
# 998  52cdef7d4bab8bd675298d32  SquareClock             12
# 999  52cdef7d4bab8bd675298d44  MyPronostic              8
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
# Your Code
pd.DataFrame(c.find(
    {"$and": [
        {'acquisition.price_amount': {'$gt': 10000}},
        {'founded_year': {"$lt": 2000}}
    ]},
    {'name': 1, 'acquisition.price_amount': 1}
).limit(11))
# Out:
#                          _id              name                   acquisition
# 0   52cdef7c4bab8bd675297d90           Postini   {'price_amount': 625000000}
# 1   52cdef7c4bab8bd675297deb          SideStep   {'price_amount': 180000000}
# 2   52cdef7c4bab8bd675297e2c        Recipezaar    {'price_amount': 25000000}
# 3   52cdef7c4bab8bd675297e37           Cyworld     {'price_amount': 7140000}
# 4   52cdef7c4bab8bd675297e89            PayPal  {'price_amount': 1500000000}
# 5   52cdef7c4bab8bd675297e97          Snapfish   {'price_amount': 300000000}
# 6   52cdef7c4bab8bd675297eaa           Neopets   {'price_amount': 160000000}
# 7   52cdef7c4bab8bd675297ee9  Sun Microsystems  {'price_amount': 7400000000}
# 8   52cdef7c4bab8bd675297efe            Zappos  {'price_amount': 1200000000}
# 9   52cdef7c4bab8bd675297f0c           Alibaba  {'price_amount': 1000000000}
# 10  52cdef7c4bab8bd675297f28             Sabre  {'price_amount': 4300000000}

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
# Your Code
pd.DataFrame(c.find({'acquisition.acquired_year': {'$gt': 2010}},{'name': 1, 'acquisition': 1}).sort('acquisition.price_amount').limit(11))
# Out:
#                          _id           name  \
# 0   52cdef7c4bab8bd675297dbf         blogTV
# 1   52cdef7c4bab8bd675297ddd        Mashery
# 2   52cdef7c4bab8bd675297d91           Geni
# 3   52cdef7c4bab8bd675297dc7      delicious
# 4   52cdef7c4bab8bd675297dab           Kyte
# 5   52cdef7c4bab8bd675297df3  Instructables
# 6   52cdef7c4bab8bd675297e1d        Seesmic
# 7   52cdef7c4bab8bd675297e06        adBrite
# 8   52cdef7c4bab8bd675297e02        Dogster
# 9   52cdef7c4bab8bd675297df4       Netvibes
# 10  52cdef7c4bab8bd675297def       KickApps
#
#                                           acquisition
# 0   {'price_amount': None, 'price_currency_code': ...
# 1   {'price_amount': None, 'price_currency_code': ...
# 2   {'price_amount': None, 'price_currency_code': ...
# 3   {'price_amount': None, 'price_currency_code': ...
# 4   {'price_amount': None, 'price_currency_code': ...
# 5   {'price_amount': None, 'price_currency_code': ...
# ...

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
# Your Code
pd.DataFrame(c.find({},{'name': 1, 'founded_year': 1}).sort('founded_year', -1))
# Out:
#                             _id                 name  founded_year
# 0      52cdef7c4bab8bd675297fec                Fixya        2013.0
# 1      52cdef7c4bab8bd67529801f                Wamba        2013.0
# 2      52cdef7c4bab8bd6752982d4            Advaliant        2013.0
# 3      52cdef7c4bab8bd67529830a                 Fluc        2013.0
# 4      52cdef7d4bab8bd675298ea7               iBazar        2013.0
# ...                         ...                  ...           ...
# 18796  52cdef7f4bab8bd67529c6ec            Embedster           NaN
# 18797  52cdef7f4bab8bd67529c6f1        Willdan Group           NaN
# 18798  52cdef7f4bab8bd67529c6f4             Geekdive           NaN
# 18799  52cdef7f4bab8bd67529c6f8          goBookmaker           NaN
# 18800  52cdef7f4bab8bd67529c6f9  EnteGreat Solutions           NaN
#
# [18801 rows x 3 columns]

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
# Your Code
pd.DataFrame(c.find({'founded_day': {"$in": [1, 2, 3, 4, 5, 6, 7]}}, {'name': 1, 'founded_day': 1}).limit(11))
# Out:
#                          _id                   name  founded_day
# 0   52cdef7c4bab8bd675297d8e               Facebook            1
# 1   52cdef7c4bab8bd675297d8f              Omnidrive            1
# 2   52cdef7c4bab8bd675297d90                Postini            2
# 3   52cdef7c4bab8bd675297d91                   Geni            1
# 4   52cdef7c4bab8bd675297d93  Fox Interactive Media            1
# 5   52cdef7c4bab8bd675297d95            StumbleUpon            1
# 6   52cdef7c4bab8bd675297d96                 Gizmoz            1
# 7   52cdef7c4bab8bd675297d9a                  Helio            1
# 8   52cdef7c4bab8bd675297d9b                   eBay            1
# 9   52cdef7c4bab8bd675297d9d                  Joost            1
# 10  52cdef7c4bab8bd675297da0               Babelgum            1

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
# Your Code
pd.DataFrame(c.find(
    {"$and": [
        {'category_code': 'web'},
        {'number_of_employees': {"$gt": 4000}}
    ]},
     {'name': 1, 'category_code': 1, 'number_of_employees': 1}
).sort ('number_of_employees', 1))
# Out:
#                         _id                           name category_code  \
# 0  52cdef7c4bab8bd67529822a                        Expedia           web
# 1  52cdef7c4bab8bd675297e96                            AOL           web
# 2  52cdef7c4bab8bd675297ea4                        Webkinz           web
# 3  52cdef7c4bab8bd675297fcb                        Rakuten           web
# 4  52cdef7c4bab8bd67529834c  Los Angeles Times Media Group           web
# 5  52cdef7d4bab8bd675299d5d                        Groupon           web
# 6  52cdef7c4bab8bd675297da3                         Yahoo!           web
# 7  52cdef7c4bab8bd675297d9b                           eBay           web
# 8  52cdef7c4bab8bd6752982a8                       Experian           web
#
#    number_of_employees
# 0                 4400
# 1                 8000
# 2                 8657
# 3                10000
# 4                10000
# 5                10000
# 6                13600
# 7                15000
# ...

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
# Your Code - Changed question to: all the companies whose currency is EUR. 

pd.DataFrame(c.find({'acquisition.price_currency_code': 'EUR'},{'name': 1, 'acquisition.price_currency_code': 1}))
# Out:
#                          _id                               name  \
# 0   52cdef7c4bab8bd675297f02                                ZYB
# 1   52cdef7d4bab8bd675298bf3                            Apertio
# 2   52cdef7d4bab8bd675298f47                  Greenfield Online
# 3   52cdef7d4bab8bd675298f94                       Mobile Trend
# 4   52cdef7d4bab8bd67529959b                  FashionFreax GmbH
# 5   52cdef7d4bab8bd675299925                  FashionFreax GmbH
# 6   52cdef7d4bab8bd67529a229                        Citizenside
# 7   52cdef7e4bab8bd67529a2fb                      Excite Europe
# 8   52cdef7e4bab8bd67529a396                         YelloYello
# 9   52cdef7e4bab8bd67529a536                            Webedia
# 10  52cdef7e4bab8bd67529a5ad                             hybris
# 11  52cdef7e4bab8bd67529a729                          Wayfinder
# 12  52cdef7e4bab8bd67529af3f                              ulike
# 13  52cdef7e4bab8bd67529b59e          Branded Payment Solutions
# ...

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
# Your Code
pd.DataFrame(c.find({'acquisition.acquired_month': {"$in": [1, 2, 3]}}, {'name': 1, 'acquisition': 1}).limit(11))
# Out:
#                          _id          name  \
# 0   52cdef7c4bab8bd675297dab          Kyte
# 1   52cdef7c4bab8bd675297db4    NetRatings
# 2   52cdef7c4bab8bd675297dbf        blogTV
# 3   52cdef7c4bab8bd675297dc0    Livestream
# 4   52cdef7c4bab8bd675297dda      iContact
# 5   52cdef7c4bab8bd675297de8       Coghead
# 6   52cdef7c4bab8bd675297dee   Dailymotion
# 7   52cdef7c4bab8bd675297df4      Netvibes
# 8   52cdef7c4bab8bd675297df8        Flickr
# 9   52cdef7c4bab8bd675297df9    BabyCenter
# 10  52cdef7c4bab8bd675297e12  Ticketmaster
#
#                                           acquisition
# 0   {'price_amount': None, 'price_currency_code': ...
# 1   {'price_amount': 327000000, 'price_currency_co...
# 2   {'price_amount': None, 'price_currency_code': ...
# 3   {'price_amount': None, 'price_currency_code': ...
# 4   {'price_amount': 169000000, 'price_currency_co...
# 5   {'price_amount': None, 'price_currency_code': ...
# 6   {'price_amount': 168000000, 'price_currency_co...
# ...

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
# Your Code
pd.DataFrame(c.find(
    {"$and": [
        {'founded_year': {'$gt': 2000}},
        {'founded_year': {"$lt": 2010}},
        {'acquisition.acquired_year': {'$gt': 2011}}
    ]},
    {'name': 1, 'founded_year': 1, 'acquisition.acquired_year': 1}
).limit(11))
# Out:
#                          _id         name  founded_year  \
# 0   52cdef7c4bab8bd675297d8a     Wetpaint          2005
# 1   52cdef7c4bab8bd675297d8d         Digg          2004
# 2   52cdef7c4bab8bd675297d91         Geni          2006
# 3   52cdef7c4bab8bd675297dbf       blogTV          2006
# 4   52cdef7c4bab8bd675297dcb    Revision3          2005
# 5   52cdef7c4bab8bd675297dda     iContact          2003
# 6   52cdef7c4bab8bd675297ddd      Mashery          2006
# 7   52cdef7c4bab8bd675297dee  Dailymotion          2005
# 8   52cdef7c4bab8bd675297def     KickApps          2004
# 9   52cdef7c4bab8bd675297df4     Netvibes          2005
# 10  52cdef7c4bab8bd675297e06      adBrite          2003
#
#                 acquisition
# 0   {'acquired_year': 2013}
# 1   {'acquired_year': 2012}
# 2   {'acquired_year': 2012}
# 3   {'acquired_year': 2013}
# 4   {'acquired_year': 2012}
# 5   {'acquired_year': 2012}
# 6   {'acquired_year': 2013}
# 7   {'acquired_year': 2013}
# ...

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
# Your Code
