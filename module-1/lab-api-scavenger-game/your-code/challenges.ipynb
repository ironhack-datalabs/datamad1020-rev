# %%
import os
from dotenv import load_dotenv
import json
import requests
import re
load_dotenv()
# Out:
# True

# %%
# Challenge 1

# %%
token = os.getenv('token')

# %%
header_token = {'Autorization': token}

# %%
url_mother = 'https://api.github.com'
repo = 'datamad1020-rev'
owner = 'ironhack-datalabs'
url_specific = f'/repos/{owner}/{repo}/forks'

endpoint = url_mother + url_specific

# %%
fork_data = requests.get(endpoint, headers = header_token).json()

# %%
import pandas as pd

# %%
len(fork_data)
# Out:
# 21

# %%
df = pd.DataFrame(fork_data)
df
# Out:
#            id                           node_id             name  \
# 0   309172162  MDEwOlJlcG9zaXRvcnkzMDkxNzIxNjI=  datamad1020-rev
# 1   306353976  MDEwOlJlcG9zaXRvcnkzMDYzNTM5NzY=  datamad1020-rev
# 2   305694744  MDEwOlJlcG9zaXRvcnkzMDU2OTQ3NDQ=  datamad1020-rev
# 3   305439178  MDEwOlJlcG9zaXRvcnkzMDU0MzkxNzg=  datamad1020-rev
# 4   305422717  MDEwOlJlcG9zaXRvcnkzMDU0MjI3MTc=  datamad1020-rev
# 5   305399167  MDEwOlJlcG9zaXRvcnkzMDUzOTkxNjc=  datamad1020-rev
# 6   305398274  MDEwOlJlcG9zaXRvcnkzMDUzOTgyNzQ=  datamad1020-rev
# 7   305396398  MDEwOlJlcG9zaXRvcnkzMDUzOTYzOTg=  datamad1020-rev
# 8   305396069  MDEwOlJlcG9zaXRvcnkzMDUzOTYwNjk=  datamad1020-rev
# 9   305395845  MDEwOlJlcG9zaXRvcnkzMDUzOTU4NDU=  datamad1020-rev
# 10  305395838  MDEwOlJlcG9zaXRvcnkzMDUzOTU4Mzg=  datamad1020-rev
# 11  305395818  MDEwOlJlcG9zaXRvcnkzMDUzOTU4MTg=  datamad1020-rev
# 12  305395675  MDEwOlJlcG9zaXRvcnkzMDUzOTU2NzU=  datamad1020-rev
# ...

# %%
url_specific2 = f'/repos/{owner}/{repo}/languages'
endpoint2 = url_mother + url_specific2

# %%
fork_data[0].get('language')
# Out:
# 'Jupyter Notebook'

# %%
languages = requests.get(endpoint2, headers = header_token).json()

# %%
len(languages)
# Out:
# 3

# %%
languages
# Out:
# {'Jupyter Notebook': 771617, 'HTML': 498316, 'Python': 38571}

# %%
# Challenge 2

# %%
url_mother = 'https://api.github.com'
repo = 'datamad1020-rev'
owner = 'ironhack-datalabs'
url_specific3 = f'/repos/{owner}/{repo}/commits'
parameters = {'since': '2020-10-28'}

endpoint = url_mother + url_specific3

# %%
response= requests.get(endpoint, params= parameters)

# %%
response.status_code
# Out:
# 200

# %%
commits=response.json()

# %%
commits
# Out:
# [{'sha': '29cc7a43e6c23714e796b920534224d045cf43f5',
#   'node_id': 'MDY6Q29tbWl0MzA0MjQ4NTM5OjI5Y2M3YTQzZTZjMjM3MTRlNzk2YjkyMDUzNDIyNGQwNDVjZjQzZjU=',
#   'commit': {'author': {'name': 'sheriffff',
#     'email': 'manuel.lopez.sheriff@gmail.com',
#     'date': '2020-11-04T19:04:32Z'},
#    'committer': {'name': 'sheriffff',
#     'email': 'manuel.lopez.sheriff@gmail.com',
#     'date': '2020-11-04T19:04:32Z'},
#    'message': 'project w3',
#    'tree': {'sha': 'eb98948a703bb88986bd33e68ade7292a8480f1a',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/trees/eb98948a703bb88986bd33e68ade7292a8480f1a'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/commits/29cc7a43e6c23714e796b920534224d045cf43f5',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
type(commits)
# Out:
# list

# %%
c = commits[0]

# %%
type(c)
# Out:
# dict

# %%
c.keys()
# Out:
# dict_keys(['sha', 'node_id', 'commit', 'url', 'html_url', 'comments_url', 'author', 'committer', 'parents'])

# %%
n_commits = len(commits)

# %%
n_commits
# Out:
# 10

# %%
# Challenge 3

# %%
url = 'https://github.com/ironhack-datalabs/scavenger'

# %%
url_mother = 'https://api.github.com'
repo3 = 'scavenger'
owner = 'ironhack-datalabs'
url_specific4 = f'/repos/{owner}/{repo3}/contents'
parameters = {'since': '2020-10-28'}

endpoint = url_mother + url_specific4

# %%
response= requests.get(endpoint)

# %%
contents= response.json()

# %%
contents
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  {'name': '15024',
#   'path': '15024',
#   'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'size': 0,
# ...

# %%
type(contents)
# Out:
# list

# %%
len(contents)
# Out:
# 26
