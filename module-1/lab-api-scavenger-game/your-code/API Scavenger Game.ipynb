# %% [markdown]
# # API Scavenger Game

# %% [markdown]
# - generar token
# - guardar en .env
# - menter .env en .gitignore
# - meter aqui la variable para poder trabajarr

# %%
# !pip install -U python-dotenv

# %%
# !pip install requests

# %%
import os
from dotenv import load_dotenv
import json
import requests
import re
load_dotenv()
# Out:
# True

# %%
token = os.getenv("token")

# %%
curl -u leticia-sobrino:734c8069acd4f6b8b13e69a7c229691bc03e4bb1 https://api.github.com/leticia-sobrino
# Out:
#   File "<ipython-input-36-11ebd6b50c59>", line 1
#     curl -u leticia-sobrino:734c8069acd4f6b8b13e69a7c229691bc03e4bb1 https://api.github.com/leticia-sobrino
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Challenge 1: Fork Languages

# %%
url = "https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/forks"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'[{"id":309172162,"node_id":"MDEwOlJlcG9zaXRvcnkzMDkxNzIxNjI=","name":"datamad1020-rev","full_name":"agalvezcorell/datamad1020-rev","private":false,"owner":{"login":"agalvezcorell","id":57899051,"node_id":"MDQ6VXNlcjU3ODk5MDUx","avatar_url":"https://avatars0.githubusercontent.com/u/57899051?v=4","gravatar_id":"","url":"https://api.github.com/users/agalvezcorell","html_url":"https://github.com/agalvezcorell","followers_url":"https://api.github.com/users/agalvezcorell/followers","following_url":"https://api.github.com/users/agalvezcorell/following{/other_user}","gists_url":"https://api.github.com/users/agalvezcorell/gists{/gist_id}","starred_url":"https://api.github.com/users/agalvezcorell/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/agalvezcorell/subscriptions","organizations_url":"https://api.github.com/users/agalvezcorell/orgs","repos_url":"https://api.github.com/users/agalvezcorell/repos","events_url":"https://api.github.com/users/agalvezcorell/events{
# ...

# %%
data = response.json()

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [{'id': 309172162,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMDkxNzIxNjI=',
#   'name': 'datamad1020-rev',
#   'full_name': 'agalvezcorell/datamad1020-rev',
#   'private': False,
#   'owner': {'login': 'agalvezcorell',
#    'id': 57899051,
#    'node_id': 'MDQ6VXNlcjU3ODk5MDUx',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/57899051?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/agalvezcorell',
#    'html_url': 'https://github.com/agalvezcorell',
#    'followers_url': 'https://api.github.com/users/agalvezcorell/followers',
#    'following_url': 'https://api.github.com/users/agalvezcorell/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/agalvezcorell/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/agalvezcorell/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/agalvezcorell/subscriptions',
#    'organizations_url': 'https://api.github.com/users/agalvezcorell/orgs',
# ...

# %%
response.headers
# Out:
# {'date': 'Tue, 03 Nov 2020 16:46:58 GMT', 'content-type': 'text/html; charset=utf-8', 'server': 'GitHub.com', 'status': '200 OK', 'vary': 'X-PJAX, Accept-Encoding, Accept, X-Requested-With, Accept-Encoding', 'etag': 'W/"55bf1b833480cd22b1800df3b93756cf"', 'cache-control': 'max-age=0, private, must-revalidate', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'x-frame-options': 'deny', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'referrer-policy': 'no-referrer-when-downgrade', 'expect-ct': 'max-age=2592000, report-uri="https://api.github.com/_private/browser/errors"', 'content-security-policy': "default-src 'none'; base-uri 'self'; block-all-mixed-content; connect-src 'self' uploads.github.com www.githubstatus.com collector.githubapp.com api.github.com www.google-analytics.com github-cloud.s3.amazonaws.com github-production-repository-file-5c1aeb.s3.amazonaws.com github-production-upload-manifest-file-7fdce7.s3.amazonaws.com gi
# ...

# %%
import pandas as pd

# %%
df =pd.DataFrame(data)

# %%
df
# Out:
#            id                           node_id             name  \
# 0   309172162  MDEwOlJlcG9zaXRvcnkzMDkxNzIxNjI=  datamad1020-rev
# 1   306353976  MDEwOlJlcG9zaXRvcnkzMDYzNTM5NzY=  datamad1020-rev
# 2   305694744  MDEwOlJlcG9zaXRvcnkzMDU2OTQ3NDQ=  datamad1020-rev
# 3   305439178  MDEwOlJlcG9zaXRvcnkzMDU0MzkxNzg=  datamad1020-rev
# 4   305422717  MDEwOlJlcG9zaXRvcnkzMDU0MjI3MTc=  datamad1020-rev
# 5   305399167  MDEwOlJlcG9zaXRvcnkzMDUzOTkxNjc=  datamad1020-rev
# 6   305398274  MDEwOlJlcG9zaXRvcnkzMDUzOTgyNzQ=  datamad1020-rev
# 7   305396398  MDEwOlJlcG9zaXRvcnkzMDUzOTYzOTg=  datamad1020-rev
# 8   305396069  MDEwOlJlcG9zaXRvcnkzMDUzOTYwNjk=  datamad1020-rev
# 9   305395845  MDEwOlJlcG9zaXRvcnkzMDUzOTU4NDU=  datamad1020-rev
# 10  305395838  MDEwOlJlcG9zaXRvcnkzMDUzOTU4Mzg=  datamad1020-rev
# 11  305395818  MDEwOlJlcG9zaXRvcnkzMDUzOTU4MTg=  datamad1020-rev
# 12  305395675  MDEwOlJlcG9zaXRvcnkzMDUzOTU2NzU=  datamad1020-rev
# ...

# %%
languages = []
for l in df["language"]:
    if l == None:
        pass
    else:
        languages.append(l)
print(list(set(languages)))
# Out:
# ['Jupyter Notebook']

# %% [markdown]
# ### Challenge 2: Count Commits

# %%
url_2 = "https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/commits"

# %%
response_2 = requests.get(url_2)

# %%
response_2.status_code
# Out:
# 200

# %%
response_2.content
# Out:
# b'[{"sha":"4260b0030dbceb627a33a31dd76e739829a85a63","node_id":"MDY6Q29tbWl0MzA0MjQ4NTM5OjQyNjBiMDAzMGRiY2ViNjI3YTMzYTMxZGQ3NmU3Mzk4MjlhODVhNjM=","commit":{"author":{"name":"sheriffff","email":"manuel.lopez.sheriff@gmail.com","date":"2020-11-02T16:47:51Z"},"committer":{"name":"sheriffff","email":"manuel.lopez.sheriff@gmail.com","date":"2020-11-02T16:47:51Z"},"message":"readme scavengers fix","tree":{"sha":"71a8246741ca6bfd66d9ee5d5cbac05bbfb1866b","url":"https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/trees/71a8246741ca6bfd66d9ee5d5cbac05bbfb1866b"},"url":"https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/commits/4260b0030dbceb627a33a31dd76e739829a85a63","comment_count":0,"verification":{"verified":false,"reason":"unsigned","signature":null,"payload":null}},"url":"https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/commits/4260b0030dbceb627a33a31dd76e739829a85a63","html_url":"https://github.com/ironhack-datalabs/datamad1020-rev/commit/42
# ...

# %%
data_2 = response_2.json()
data_2
# Out:
# [{'sha': '4260b0030dbceb627a33a31dd76e739829a85a63',
#   'node_id': 'MDY6Q29tbWl0MzA0MjQ4NTM5OjQyNjBiMDAzMGRiY2ViNjI3YTMzYTMxZGQ3NmU3Mzk4MjlhODVhNjM=',
#   'commit': {'author': {'name': 'sheriffff',
#     'email': 'manuel.lopez.sheriff@gmail.com',
#     'date': '2020-11-02T16:47:51Z'},
#    'committer': {'name': 'sheriffff',
#     'email': 'manuel.lopez.sheriff@gmail.com',
#     'date': '2020-11-02T16:47:51Z'},
#    'message': 'readme scavengers fix',
#    'tree': {'sha': '71a8246741ca6bfd66d9ee5d5cbac05bbfb1866b',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/trees/71a8246741ca6bfd66d9ee5d5cbac05bbfb1866b'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/commits/4260b0030dbceb627a33a31dd76e739829a85a63',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
df_commits =pd.DataFrame(data_2)
df_commits
# Out:
#                                          sha  \
# 0   4260b0030dbceb627a33a31dd76e739829a85a63
# 1   56c1aa10c26d062c4b19848da442f9d5cc0e9f30
# 2   52bf5810f1e309b50493513580ed47358d1dff0e
# 3   cd314fdcdf00f161dc093d03e3d73d6c42d10e64
# 4   4ab3b3ef149bb0bc723bc7fd1835a964525067e2
# 5   8a934386e14d73d739eb7bfe188513ed6a675540
# 6   316d00933d20a5dbbdf6bb93e25bb3ce3e51d40a
# 7   52f82d21a7445f61c0d05cc9558631ac8fbddacf
# 8   c4d2f6abc43bb144b5d9ab5997c700426b05510f
# 9   76826484b3c10a4e1b00b26e62edcadfdb1e8f06
# 10  b6fe5417a24a291c87896055f4a5f9c47977ea15
# 11  aa643e8af5f8b68879e08eb7c609d2512eed2459
# 12  db7688dd8c3120c1a78151b404b9168f0c0c4d5a
# 13  6076de0e572af1a835613f9f9bc1bd4782b700ed
# 14  59c6195205a2067373d27b82b42c103ac63a6749
# 15  6b7aaf850cd8c27809e0c7fbb75922cdcad2babf
# 16  f8a57437d8cc875016cc8c7e5cdfd5d20d87f80f
# 17  2b192701f44c885f875adf04f3d9b973bd36937a
# 18  c7aa089728a649bc70c3b650bdf014258522d179
# 19  4d5fe09bbcc2115207092bae62bb03c60192f909
# ...

# %%
type(df_commits.commit)
# Out:
# pandas.core.series.Series

# %%
commits = []
for c in df_commits["commit"]:
    if c == None:
        pass
    else:
        commits.append(c)
print(list(commits))

print(len(commits))
# Out:
# [{'author': {'name': 'sheriffff', 'email': 'manuel.lopez.sheriff@gmail.com', 'date': '2020-11-02T16:47:51Z'}, 'committer': {'name': 'sheriffff', 'email': 'manuel.lopez.sheriff@gmail.com', 'date': '2020-11-02T16:47:51Z'}, 'message': 'readme scavengers fix', 'tree': {'sha': '71a8246741ca6bfd66d9ee5d5cbac05bbfb1866b', 'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/trees/71a8246741ca6bfd66d9ee5d5cbac05bbfb1866b'}, 'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/git/commits/4260b0030dbceb627a33a31dd76e739829a85a63', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None}}, {'author': {'name': 'ironhack-datalabs', 'email': 'agalvezcorell@gmail.com', 'date': '2020-10-30T09:29:13Z'}, 'committer': {'name': 'ironhack-datalabs', 'email': 'agalvezcorell@gmail.com', 'date': '2020-10-30T09:29:13Z'}, 'message': 'txt myproject', 'tree': {'sha': 'bdbe22c3904a29d980684618bcff2b910af816d5', 'url
# ...

# %%
print(len(commits))
# Out:
# 24

# %% [markdown]
# ### Challenge 3: Hidden Cold Joke

# %%
url_cold_joke = "https://github.com/ironhack-datalabs/scavenger"

# %%
response_joke = requests.get(url_cold_joke)

# %%
response_joke.status_code
# Out:
# 200

# %%
response_joke.content
# Out:
# b'\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-rejAsoJJGKFUHDunQEchnrzTFCP8j+HW+0BGXl/Fz4iEznxtf+ZDMP2v224+Na1KQbg1MmLqMl7ErrS6mxTgRw==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-ade8c0b2824918a1541c3ba74047219e.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-jlDry7Lvhm9Xj5gH5j+6IESsbRyoGnFJMhI3zWyssDHvBLv1By6KSCiMJ
# ...

# %%
response_joke.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-192-82484f51a1a9> in <module>
# ----> 1 response_joke.json()
#
# c:\users\leticia\documents\miniconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# c:\users\leticia\documents\miniconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ...
